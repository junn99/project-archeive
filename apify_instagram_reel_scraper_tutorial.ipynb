# %% [markdown]
# # 🎬 Apify Instagram Reel Scraper 튜토리얼
#
# 이 노트북에서는 Apify의 Instagram Reel Scraper를 Python으로 활용하는 방법을 단계별로 학습합니다.
#
# ## 📋 학습 목표
# 1. Apify Client 설치 및 설정
# 2. Instagram Reel 데이터 수집 기본 사용법
# 3. 다양한 입력 옵션 활용
# 4. 수집된 데이터 분석 및 활용
# 5. 비동기(Async) 클라이언트 사용법
# 6. 에러 처리 및 베스트 프랙티스
#
# ---

# %% [markdown]
# ## 1️⃣ 환경 설정
#
# ### 1.1 필요한 패키지 설치

# %%
# Apify Client 및 데이터 분석용 패키지 설치
# !pip install apify-client pandas matplotlib

# %% [markdown]
# ### 1.2 라이브러리 임포트

# %%
from apify_client import ApifyClient
import pandas as pd
import json
from datetime import datetime
# import matplotlib.pyplot as plt
from dotenv import load_dotenv
load_dotenv()

print("✅ 라이브러리 임포트 완료!")
# Out:
# ✅ 라이브러리 임포트 완료!

# %% [markdown]
# ### 1.3 Apify API 토큰 설정
#
# API 토큰은 [Apify Console > Settings > Integrations](https://console.apify.com/settings/integrations)에서 확인할 수 있습니다.
#
# > ⚠️ **보안 주의**: API 토큰은 절대 공개 저장소에 커밋하지 마세요!

# %%
# 방법 1: 직접 입력 (테스트용)
# APIFY_TOKEN = "<YOUR_API_TOKEN>"  # 여기에 실제 토큰 입력

# 방법 2: 환경 변수 사용 (권장)
import os
APIFY_API_TOKEN = os.environ.get("APIFY_TOKEN")

# 클라이언트 초기화
client = ApifyClient(APIFY_API_TOKEN)
print("✅ Apify Client 초기화 완료!")
# Out:
# ✅ Apify Client 초기화 완료!

# %% [markdown]
# ---
#
# ## 2️⃣ 기본 사용법: Instagram Reel 스크래핑
#
# ### 2.1 Actor 정보
#
# Instagram Reel Scraper의 Actor ID는 `xMc5Ga1oCONPmWJIa`입니다.
#
# ### 2.2 기본 스크래핑 예제

# %%
# Actor 입력 설정
run_input = {
    "username": ["ddobini619"],  # 스크래핑할 Instagram 사용자명
    "resultsLimit": 5,       # 가져올 릴스 개수 (비용 절약을 위해 10개로 제한)
}

print("📋 입력 설정:")
print(json.dumps(run_input, indent=2))
# Out:
# 📋 입력 설정:
# {
#   "username": [
#     "ddobini619"
#   ],
#   "resultsLimit": 5
# }

# %%
# Actor 실행 (완료될 때까지 대기)
print("🚀 Instagram Reel Scraper 실행 중...")
print("⏳ 완료까지 잠시 기다려주세요...")

run = client.actor("xMc5Ga1oCONPmWJIa").call(run_input=run_input)

print(f"\n✅ 실행 완료!")
print(f"📊 Run ID: {run['id']}")
print(f"📁 Dataset ID: {run['defaultDatasetId']}")
# Out:
# 🚀 Instagram Reel Scraper 실행 중...
# ⏳ 완료까지 잠시 기다려주세요...
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> Status: RUNNING, Message:
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:55.616Z ACTOR: Pulling container image of build gWxOmlKJ3WrmuIQE3 from registry.
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:55.618Z ACTOR: Creating container.
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:56.237Z ACTOR: Starting container.
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:56.238Z ACTOR: Running under "LIMITED_PERMISSIONS" permission level.
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:56.877Z INFO  System info {"apifyVersion":"3.5.1","apifyClientVersion":"2.19.0","crawleeVersion":"3.15.3","osType":"Linux","nodeVersion":"v22.21.1"}
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:56.972Z INFO  Results Limit [object Object], ACTOR_MAX_PAID_DATASET_ITEMS
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:57.083Z INFO  Starting Apify client's scheduler {"clientName":"CLIENT"}
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:57.179Z INFO  [Status message]: Starting the scraper with 1 direct URL(s)
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> Status: RUNNING, Message: Starting the crawler.
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:57:57.352Z INFO  CheerioCrawler: Starting the crawler.
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:58:06.503Z INFO  CheerioCrawler: All requests from the queue have been processed, the crawler will shut down.
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:58:06.642Z INFO  CheerioCrawler: Final request statistics: {"requestsFinished":7,"requestsFailed":0,"retryHistogram":[7],"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":2595,"requestsFinishedPerMinute":45,"requestsFailedPerMinute":0,"requestTotalDurationMillis":18162,"requestsTotal":7,"crawlerRuntimeMillis":9406}
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:58:06.644Z INFO  CheerioCrawler: Finished! Total 7 requests: 7 succeeded, 0 failed. {"terminal":true}
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:58:06.645Z INFO  [Status message]: Scraper finished
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> 2025-12-23T13:58:06.748Z INFO  Stopping Apify client's scheduler {"clientName":"CLIENT"}
# [apify.instagram-reel-scraper runId:rUogIKhgt5f7GXgIX] -> Status: SUCCEEDED, Message: Scraper finished
# ✅ 실행 완료!
# 📊 Run ID: rUogIKhgt5f7GXgIX
# 📁 Dataset ID: xsAENbqD3HzYdF9rj

# %%
# 결과 데이터 가져오기
dataset_items = list(client.dataset(run["defaultDatasetId"]).iterate_items())

print(f"📥 총 {len(dataset_items)}개의 릴스 데이터를 가져왔습니다!")

# %%
# 첫 번째 결과 확인
if dataset_items:
    first_reel = dataset_items[0]
    print("🎬 첫 번째 릴스 데이터 구조:")
    print(json.dumps(first_reel, indent=2, ensure_ascii=False, default=str)[:2000])
    print("\n... (일부 생략)")

# %% [markdown]
# ---
#
# ## 3️⃣ 수집 가능한 데이터 필드
#
# Instagram Reel Scraper가 수집하는 주요 데이터 필드를 살펴봅시다.

# %%
# 데이터 필드 분석
if dataset_items:
    sample = dataset_items[0]
    
    print("📋 수집 가능한 주요 필드:")
    print("=" * 50)
    
    field_descriptions = {
        "id": "릴스 고유 ID",
        "shortCode": "릴스 단축 코드",
        "url": "릴스 URL",
        "caption": "캡션 (설명 텍스트)",
        "hashtags": "해시태그 목록",
        "mentions": "멘션된 사용자",
        "likesCount": "좋아요 수",
        "commentsCount": "댓글 수",
        "videoViewCount": "조회수",
        "videoPlayCount": "재생 수",
        "sharesCount": "공유 수",
        "videoDuration": "영상 길이 (초)",
        "timestamp": "게시 시간",
        "ownerUsername": "게시자 사용자명",
        "ownerFullName": "게시자 이름",
        "transcript": "영상 자막/스크립트",
        "videoUrl": "영상 다운로드 URL",
        "images": "썸네일 이미지 URL",
        "musicInfo": "음악 정보",
        "latestComments": "최근 댓글 (최대 10개)",
    }
    
    for field, desc in field_descriptions.items():
        value = sample.get(field, "N/A")
        if isinstance(value, list):
            value = f"[{len(value)} items]"
        elif isinstance(value, dict):
            value = "{...}"
        elif isinstance(value, str) and len(value) > 50:
            value = value[:50] + "..."
        print(f"  • {field}: {desc}")
        print(f"    └─ 예시: {value}")

# %% [markdown]
# ---
#
# ## 4️⃣ 다양한 입력 옵션 활용
#
# ### 4.1 전체 입력 옵션 설명

# %%
# 모든 입력 옵션 예시
full_input_example = {
    # ===== 기본 입력 =====
    "username": ["natgeo", "nasa"],        # 사용자명 리스트
    # "directUrls": ["https://www.instagram.com/reel/ABC123/"],  # 특정 릴스 URL
    
    # ===== 결과 제한 =====
    "resultsLimit": 30,                     # 수집할 최대 릴스 개수
    
    # ===== 추가 데이터 옵션 =====
    "includeSharesCount": False,            # 공유 수 포함 여부 (추가 비용 발생)
    "includeTranscript": False,             # 자막/스크립트 포함 여부
    "includeDownloadedVideo": False,        # 영상 다운로드 여부
    
    # ===== 필터링 옵션 =====
    "skipPinnedPosts": None,                # 고정 게시물 건너뛰기 여부
}

print("📋 전체 입력 옵션 예시:")
print(json.dumps(full_input_example, indent=2))

# %% [markdown]
# ### 4.2 여러 계정 동시 스크래핑

# %%
# 여러 계정에서 릴스 수집
multi_account_input = {
    "username": ["natgeo", "nasa", "bbcearth"],  # 여러 계정
    "resultsLimit": 5,  # 계정당 5개씩
}

print("🔧 여러 계정 스크래핑 설정:")
print(json.dumps(multi_account_input, indent=2))

# 실제 실행하려면 아래 주석 해제
# run = client.actor("xMc5Ga1oCONPmWJIa").call(run_input=multi_account_input)

# %% [markdown]
# ### 4.3 특정 릴스 URL로 스크래핑

# %%
# 특정 릴스 URL 직접 지정
direct_url_input = {
    "directUrls": [
        "https://www.instagram.com/reel/ABC123/",
        "https://www.instagram.com/p/XYZ789/",
    ],
}

print("🔗 직접 URL 스크래핑 설정:")
print(json.dumps(direct_url_input, indent=2))

# %% [markdown]
# ### 4.4 자막(Transcript) 포함 스크래핑

# %%
# 자막/스크립트 포함 옵션
transcript_input = {
    "username": ["tedtalks"],
    "resultsLimit": 5,
    "includeTranscript": True,  # 자막 포함!
}

print("📝 자막 포함 스크래핑 설정:")
print(json.dumps(transcript_input, indent=2))
print("\n💡 Tip: 자막은 릴스의 음성을 텍스트로 변환한 것입니다.")

# %% [markdown]
# ---
#
# ## 5️⃣ 데이터 분석 및 시각화
#
# 수집된 데이터를 Pandas DataFrame으로 변환하여 분석해봅시다.

# %%
# DataFrame으로 변환
if dataset_items:
    df = pd.DataFrame(dataset_items)
    
    # 주요 컬럼만 선택
    columns_to_display = [
        'shortCode', 'ownerUsername', 'likesCount', 
        'commentsCount', 'videoViewCount', 'videoDuration', 'timestamp'
    ]
    
    available_columns = [col for col in columns_to_display if col in df.columns]
    df_display = df[available_columns].copy()
    
    print("📊 수집된 릴스 데이터 (주요 컬럼):")
    display(df_display)

# %%
# 기본 통계
if dataset_items and 'likesCount' in df.columns:
    print("📈 기본 통계:")
    print("=" * 40)
    print(f"총 릴스 개수: {len(df)}")
    print(f"평균 좋아요 수: {df['likesCount'].mean():,.0f}")
    print(f"최대 좋아요 수: {df['likesCount'].max():,.0f}")
    print(f"평균 댓글 수: {df['commentsCount'].mean():,.0f}")
    
    if 'videoDuration' in df.columns:
        print(f"평균 영상 길이: {df['videoDuration'].mean():.1f}초")

# %%
# 시각화: 좋아요 수 분포
if dataset_items and 'likesCount' in df.columns:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # 좋아요 수 막대 그래프
    axes[0].barh(range(len(df)), df['likesCount'].values, color='coral')
    axes[0].set_yticks(range(len(df)))
    axes[0].set_yticklabels(df['shortCode'].values[::-1] if 'shortCode' in df.columns else range(len(df)))
    axes[0].set_xlabel('좋아요 수')
    axes[0].set_title('릴스별 좋아요 수')
    axes[0].invert_yaxis()
    
    # 영상 길이 분포 (있는 경우)
    if 'videoDuration' in df.columns:
        axes[1].hist(df['videoDuration'], bins=10, color='steelblue', edgecolor='white')
        axes[1].set_xlabel('영상 길이 (초)')
        axes[1].set_ylabel('빈도')
        axes[1].set_title('영상 길이 분포')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 5.1 해시태그 분석

# %%
# 해시태그 빈도 분석
if dataset_items and 'hashtags' in df.columns:
    all_hashtags = []
    for hashtags in df['hashtags']:
        if isinstance(hashtags, list):
            all_hashtags.extend(hashtags)
    
    if all_hashtags:
        hashtag_counts = pd.Series(all_hashtags).value_counts()
        print("🏷️ 가장 많이 사용된 해시태그:")
        print(hashtag_counts.head(10))
    else:
        print("📭 수집된 릴스에 해시태그가 없습니다.")

# %% [markdown]
# ### 5.2 댓글 분석

# %%
# 최근 댓글 분석
if dataset_items and 'latestComments' in df.columns:
    all_comments = []
    
    for idx, row in df.iterrows():
        comments = row.get('latestComments', [])
        if isinstance(comments, list):
            for comment in comments:
                if isinstance(comment, dict):
                    all_comments.append({
                        'reel_id': row.get('shortCode', ''),
                        'text': comment.get('text', ''),
                        'username': comment.get('ownerUsername', ''),
                        'likes': comment.get('likesCount', 0),
                    })
    
    if all_comments:
        comments_df = pd.DataFrame(all_comments)
        print(f"💬 총 {len(comments_df)}개의 댓글 수집됨")
        print("\n📝 댓글 샘플:")
        display(comments_df.head(10))

# %% [markdown]
# ---
#
# ## 6️⃣ 데이터 저장
#
# ### 6.1 CSV로 저장

# %%
# CSV 파일로 저장
if dataset_items:
    # 주요 컬럼만 선택하여 저장
    export_columns = [
        'id', 'shortCode', 'url', 'caption', 'ownerUsername',
        'likesCount', 'commentsCount', 'videoViewCount', 
        'videoDuration', 'timestamp'
    ]
    
    available_export_cols = [col for col in export_columns if col in df.columns]
    df_export = df[available_export_cols].copy()
    
    filename = f"instagram_reels_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    df_export.to_csv(filename, index=False, encoding='utf-8-sig')
    print(f"✅ CSV 파일 저장 완료: {filename}")

# %% [markdown]
# ### 6.2 JSON으로 저장

# %%
# JSON 파일로 저장 (전체 데이터)
if dataset_items:
    filename = f"instagram_reels_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(dataset_items, f, ensure_ascii=False, indent=2, default=str)
    
    print(f"✅ JSON 파일 저장 완료: {filename}")

# %% [markdown]
# ---
#
# ## 7️⃣ 비동기(Async) 클라이언트 사용법
#
# 대량의 데이터를 처리하거나 여러 작업을 병렬로 실행할 때 비동기 클라이언트를 사용합니다.

# %%
# 비동기 클라이언트 예제
import asyncio
from apify_client import ApifyClientAsync

async def scrape_reels_async(usernames: list, results_limit: int = 10):
    """
    비동기로 Instagram 릴스를 스크래핑합니다.
    
    Args:
        usernames: 스크래핑할 사용자명 리스트
        results_limit: 수집할 릴스 개수
    
    Returns:
        수집된 릴스 데이터 리스트
    """
    async_client = ApifyClientAsync(APIFY_API_TOKEN)
    
    run_input = {
        "username": usernames,
        "resultsLimit": results_limit,
    }
    
    # Actor 실행 및 대기
    actor_client = async_client.actor("xMc5Ga1oCONPmWJIa")
    run_result = await actor_client.call(run_input=run_input)
    
    if run_result is None:
        print("❌ Actor 실행 실패")
        return []
    
    # 데이터셋에서 결과 가져오기
    dataset_client = async_client.dataset(run_result['defaultDatasetId'])
    items = await dataset_client.list_items()
    
    return items.items if items else []

print("📋 비동기 스크래핑 함수 정의 완료!")
print("\n사용 예시:")
print('results = await scrape_reels_async(["natgeo"], results_limit=5)')

# %%
# 비동기 함수 실행 (Jupyter에서는 await 직접 사용 가능)
# 아래 코드를 실행하려면 주석을 해제하세요

# async_results = await scrape_reels_async(["natgeo"], results_limit=3)
# print(f"✅ 비동기로 {len(async_results)}개의 릴스 수집 완료!")

# %% [markdown]
# ---
#
# ## 8️⃣ 에러 처리 및 베스트 프랙티스
#
# ### 8.1 안전한 스크래핑 함수

# %%
def safe_scrape_reels(
    usernames: list,
    results_limit: int = 10,
    include_transcript: bool = False,
    timeout_secs: int = 300
) -> list:
    """
    에러 처리가 포함된 안전한 릴스 스크래핑 함수
    
    Args:
        usernames: 스크래핑할 사용자명 리스트
        results_limit: 수집할 릴스 개수
        include_transcript: 자막 포함 여부
        timeout_secs: 타임아웃 (초)
    
    Returns:
        수집된 릴스 데이터 리스트
    """
    try:
        # 입력 검증
        if not usernames:
            raise ValueError("사용자명 리스트가 비어있습니다.")
        
        if results_limit < 1 or results_limit > 1000:
            raise ValueError("results_limit는 1~1000 사이여야 합니다.")
        
        # 입력 구성
        run_input = {
            "username": usernames,
            "resultsLimit": results_limit,
            "includeTranscript": include_transcript,
        }
        
        print(f"🚀 스크래핑 시작: {usernames}")
        print(f"   - 최대 결과: {results_limit}개")
        print(f"   - 자막 포함: {include_transcript}")
        
        # Actor 실행
        run = client.actor("xMc5Ga1oCONPmWJIa").call(
            run_input=run_input,
            timeout_secs=timeout_secs
        )
        
        # 결과 확인
        if run is None:
            print("❌ Actor 실행 결과가 없습니다.")
            return []
        
        # 상태 확인
        status = run.get('status')
        if status != 'SUCCEEDED':
            print(f"⚠️ Actor 상태: {status}")
            if status == 'FAILED':
                print(f"   에러 메시지: {run.get('statusMessage', 'N/A')}")
                return []
        
        # 데이터 가져오기
        items = list(client.dataset(run["defaultDatasetId"]).iterate_items())
        print(f"✅ 스크래핑 완료: {len(items)}개의 릴스 수집")
        
        return items
        
    except ValueError as e:
        print(f"❌ 입력 오류: {e}")
        return []
    
    except Exception as e:
        print(f"❌ 예상치 못한 오류: {type(e).__name__}: {e}")
        return []

print("✅ 안전한 스크래핑 함수 정의 완료!")

# %%
# 안전한 함수 사용 예시
# results = safe_scrape_reels(
#     usernames=["natgeo"],
#     results_limit=5,
#     include_transcript=True
# )

# %% [markdown]
# ### 8.2 베스트 프랙티스
#
# 1. **API 토큰 보안**
#    - 환경 변수나 시크릿 매니저 사용
#    - `.env` 파일은 `.gitignore`에 추가
#
# 2. **비용 관리**
#    - `resultsLimit`를 적절히 설정
#    - 불필요한 옵션 (transcript, video download) 비활성화
#    - 테스트 시 소량의 데이터만 수집
#
# 3. **에러 처리**
#    - try-except로 예외 처리
#    - 타임아웃 설정
#    - 재시도 로직 구현
#
# 4. **Rate Limiting**
#    - 대량 요청 시 적절한 딜레이 추가
#    - Apify의 사용량 제한 확인

# %% [markdown]
# ---
#
# ## 9️⃣ 실전 예제: 경쟁사 분석 봇
#
# 여러 계정의 릴스를 수집하고 비교 분석하는 예제입니다.

# %%
def analyze_competitors(usernames: list, results_per_account: int = 10):
    """
    경쟁사 Instagram 릴스 분석
    
    Args:
        usernames: 분석할 계정 리스트
        results_per_account: 계정당 수집할 릴스 개수
    """
    print("📊 경쟁사 분석 시작")
    print(f"   분석 대상: {usernames}")
    print("=" * 50)
    
    # 데이터 수집
    run_input = {
        "username": usernames,
        "resultsLimit": results_per_account * len(usernames),
    }
    
    run = client.actor("xMc5Ga1oCONPmWJIa").call(run_input=run_input)
    items = list(client.dataset(run["defaultDatasetId"]).iterate_items())
    
    if not items:
        print("❌ 데이터를 수집하지 못했습니다.")
        return
    
    df = pd.DataFrame(items)
    
    # 계정별 통계
    print("\n📈 계정별 성과 요약:")
    print("-" * 50)
    
    account_stats = df.groupby('ownerUsername').agg({
        'likesCount': ['mean', 'max', 'sum'],
        'commentsCount': ['mean', 'max'],
        'id': 'count'
    }).round(0)
    
    account_stats.columns = [
        '평균_좋아요', '최대_좋아요', '총_좋아요',
        '평균_댓글', '최대_댓글', '릴스_수'
    ]
    
    display(account_stats)
    
    # 인기 릴스 Top 5
    print("\n🏆 전체 인기 릴스 Top 5 (좋아요 기준):")
    print("-" * 50)
    
    top_reels = df.nlargest(5, 'likesCount')[[
        'ownerUsername', 'shortCode', 'likesCount', 'commentsCount'
    ]]
    display(top_reels)
    
    return df

print("✅ 경쟁사 분석 함수 정의 완료!")
print("\n사용 예시:")
print('df = analyze_competitors(["natgeo", "nasa"], results_per_account=10)')

# %% [markdown]
# ---
#
# ## 🔟 요약 및 다음 단계
#
# ### 학습한 내용
# - ✅ Apify Client 설치 및 초기화
# - ✅ Instagram Reel Scraper 기본 사용법
# - ✅ 다양한 입력 옵션 활용
# - ✅ Pandas를 활용한 데이터 분석
# - ✅ 비동기 클라이언트 사용법
# - ✅ 에러 처리 및 베스트 프랙티스
#
# ### 추가 학습 자료
# - [Apify Python Client 공식 문서](https://docs.apify.com/api/client/python/)
# - [Instagram Reel Scraper 상세 문서](https://apify.com/apify/instagram-reel-scraper)
# - [Apify Academy](https://docs.apify.com/academy)
#
# ### 관련 Apify Actors
# - [Instagram Hashtag Scraper](https://apify.com/apify/instagram-hashtag-scraper) - 해시태그 기반 릴스 검색
# - [Instagram Comment Scraper](https://apify.com/apify/instagram-comment-scraper) - 댓글 전체 수집
# - [Instagram Profile Scraper](https://apify.com/apify/instagram-profile-scraper) - 프로필 정보 수집

# %% [markdown]
# ---
#
# ## 💡 연습 문제
#
# 1. **기본**: 좋아하는 브랜드 3개의 최근 릴스 5개씩 수집해보세요.
#
# 2. **중급**: 수집한 데이터에서 가장 많이 사용된 해시태그 Top 10을 시각화하세요.
#
# 3. **고급**: 비동기 함수를 활용해 10개 이상의 계정을 병렬로 스크래핑하고, 각 계정의 평균 engagement rate를 계산하세요.
#    - Engagement Rate = (좋아요 + 댓글) / 조회수 × 100

# %%
# 연습 문제 풀이 공간
# 여기에 코드를 작성하세요!
